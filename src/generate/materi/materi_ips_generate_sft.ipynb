# %% [markdown]
# # CELL 1 — Import & Mount Google Drive

# %%
import os
import json
import random
import requests
import time
from google.colab import drive
from google.colab import userdata

drive.mount('/content/drive', force_remount=True)
print("Google Drive berhasil di-mount dengan akses penuh!")
# Out:
# Mounted at /content/drive
# Google Drive berhasil di-mount dengan akses penuh!

# %% [markdown]
# # CELL 2 — Parameter, Konfigurasi API & Direktori

# %%
# 1. Parameter Utama
PILIHAN_MODEL  = "gemini"
MATA_PELAJARAN = "IPS" # sesuaikan

# 2. Opsi Pengacakan Skenario
OPSI_KOGNITIF = ["low", "middle", "high"]
OPSI_EMOSI    = ["antusias", "bingung", "bosan", "frustrasi", "tidak_terdeteksi"]
OPSI_INSIDEN  = ["0x", "1x", "2x"]

# 3. Konfigurasi Direktori
ROOT_DIR = "/content/drive/MyDrive/sft_v4/" #sesuaikan nama folder prompt
DIR_SUMBER_DATA = os.path.join(ROOT_DIR, f"output_{MATA_PELAJARAN.lower()}_mpe/") #sesuaikan nama folder sumber

# 4. Konfigurasi API
if PILIHAN_MODEL == "gemini":
    MODEL_NAME = "gemini-2.5-flash-lite"
    API_KEY    = userdata.get('TOKEN_API')
    URL        = "https://openrouter.ai/api/v1/chat/completions"
    print(f"Model aktif: {MODEL_NAME}")
# Out:
# Model aktif: gemini-2.5-flash-lite

# %% [markdown]
# # CELL 3 — Scan File Sumber

# %%
import os
import glob
import random
import json
import requests
import time

if 'hasil_dataset' not in globals():
    hasil_dataset = []

# Fungsi pencari file di dalam output_ips_mpe
def kumpulkan_file_sumber(base_dir):
    kumpulan_file = []
    # Cari ke semua subfolder
    search_pattern = os.path.join(base_dir, "**", "*.json")
    semua_file = glob.glob(search_pattern, recursive=True)

    for file_path in semua_file:
      # Hanya mengambil file dari folder materi
        if "/materi/" in file_path:
            kumpulan_file.append(file_path)

    return kumpulan_file

daftar_file_sumber = kumpulkan_file_sumber(DIR_SUMBER_DATA)
print(f"Berhasil menemukan {len(daftar_file_sumber)} file materi.")
# Out:
# Berhasil menemukan 810 file materi.

# %% [markdown]
# # CELL 4 — Perakit Prompt

# %%
def baca_md(path_file): #baca isi file .md
    try:
        with open(path_file, "r", encoding="utf-8") as f:
            return f.read().strip()
    except FileNotFoundError:
        return ""

def get_prompts_dinamis(kognitif, emosi, oot, bad, teks_konteks_jadi, prefix_siswa):
    with open(PATH_BASE_SYS, "r", encoding="utf-8") as f:
        sys_prompt = f.read()
    with open(PATH_BASE_USR, "r", encoding="utf-8") as f:
        usr_prompt = f.read()

    # RAKIT KOMPONEN
    # 1. membuka file base_system dan base_user
    # 2. membaca file-file komponen
    teks_treat_kognitif = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"treatment_kognitif/{kognitif}.md"))
    teks_treat_emosi    = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"treatment_emosi/{emosi}.md"))
    teks_aturan_oot = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"aturan_oot_bad/oot_{oot}.md")) if oot != "0x" else ""
    teks_aturan_bad = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"aturan_oot_bad/bad_{bad}.md")) if bad != "0x" else ""

    larangan_emosi = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"larangan_tambahan/{emosi}.md"))
    larangan_oot   = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"larangan_tambahan/oot.md")) if oot != "0x" else ""
    teks_larangan  = f"{larangan_emosi}\n{larangan_oot}".strip()

    if bad != "0x": teks_struktur = baca_md(os.path.join(DIR_KOMPONEN_SYS, "struktur_respons/bad.md"))
    elif oot != "0x": teks_struktur = baca_md(os.path.join(DIR_KOMPONEN_SYS, "struktur_respons/oot.md"))
    else: teks_struktur = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"struktur_respons/{emosi}.md"))

    teks_karakter_kognitif = baca_md(os.path.join(DIR_KOMPONEN_USR, f"karakter_siswa/kognitif/{kognitif}.md"))
    teks_karakter_emosi    = baca_md(os.path.join(DIR_KOMPONEN_USR, f"karakter_siswa/emosi/{emosi}.md"))
    teks_karakter_oot = baca_md(os.path.join(DIR_KOMPONEN_USR, f"karakter_siswa/konteks/oot_{oot}.md")) if oot != "0x" else ""
    teks_karakter_bad = baca_md(os.path.join(DIR_KOMPONEN_USR, f"karakter_siswa/konteks/bad_{bad}.md")) if bad != "0x" else ""

    # 3. mencari tulisan seperti [LABEL_EMOSI], menggantinya dengan teks komponen asli menggunakan perintah .replace()
    # SUNTIK KE SYSTEM
    sys_prompt = sys_prompt.replace("[LABEL_KOGNITIF]", kognitif.upper())
    sys_prompt = sys_prompt.replace("[LABEL_EMOSI]", emosi.upper())
    sys_prompt = sys_prompt.replace("[JUMLAH_OOT]", oot)
    sys_prompt = sys_prompt.replace("[JUMLAH_BAD]", bad)
    sys_prompt = sys_prompt.replace("[ISI_KONTEKS]", teks_konteks_jadi)
    sys_prompt = sys_prompt.replace("[TEKS_TREATMENT_KOGNITIF]", teks_treat_kognitif)
    sys_prompt = sys_prompt.replace("[TEKS_TREATMENT_EMOSI]", teks_treat_emosi)
    sys_prompt = sys_prompt.replace("[TEKS_ATURAN_OOT]", teks_aturan_oot)
    sys_prompt = sys_prompt.replace("[TEKS_ATURAN_BAD]", teks_aturan_bad)
    sys_prompt = sys_prompt.replace("[LARANGAN_TAMBAHAN_DINAMIS]", teks_larangan)
    sys_prompt = sys_prompt.replace("[STRUKTUR_RESPONS_DINAMIS]", teks_struktur)

    # SUNTIK KE USER
    usr_prompt = usr_prompt.replace("[LABEL_EMOSI]", emosi.upper())
    usr_prompt = usr_prompt.replace("[FILE_KONTEKS]", teks_konteks_jadi)
    usr_prompt = usr_prompt.replace("[TEKS_KARAKTER_KOGNITIF]", teks_karakter_kognitif)
    usr_prompt = usr_prompt.replace("[TEKS_KARAKTER_EMOSI]", teks_karakter_emosi)
    usr_prompt = usr_prompt.replace("[TEKS_KARAKTER_OOT]", teks_karakter_oot)
    usr_prompt = usr_prompt.replace("[TEKS_KARAKTER_BAD]", teks_karakter_bad)
    usr_prompt = usr_prompt.replace("[PREFIX_SISWA]", prefix_siswa)

    # LOGIKA JUMLAH TURN
    if kognitif == "low" or emosi in ["frustrasi", "bingung"]:
        min_t, max_t = 10, 15
    elif oot != "0x" or bad != "0x":
        min_t, max_t = 7, 10
    else:
        min_t, max_t = 3, 7

    jumlah_turn = str(random.randint(min_t, max_t))
    usr_prompt = usr_prompt.replace("[JUMLAH_TURN]", jumlah_turn)

    return sys_prompt, usr_prompt, int(jumlah_turn)

# %% [markdown]
# # CELL 5 — Proses Generate

# %%
import os
import json
import random
import itertools
import time
import requests

# ==========================================
# 1. KONFIGURASI BUKU ABSEN MASTER
# ==========================================
FILE_BUKU_ABSEN = "/content/drive/MyDrive/output_sft_baru/buku_absen_materi_ips.json"

# ==========================================
# 2. TARGET RUN
# ==========================================
TARGET_JUMLAH_DATA = 100
MAX_RETRIES        = 3
jumlah_sukses      = 0

# ==========================================
# TAHAP A: BIKIN BUKU ABSEN (1.667 DATA MATERI)
# ==========================================
if not os.path.exists(FILE_BUKU_ABSEN):
    print("Buku Absen Materi belum ada! Membuat 1.667 tiket kombinasi baru...")

    LIST_KURIKULUM = ["Kurikulum Merdeka", "KTSP", "K-13"]
    LIST_TIPE      = ["materi"] # HANYA MATERI
    OPSI_KOGNITIF  = ["low", "middle", "high"]
    OPSI_EMOSI     = ["antusias", "bingung", "bosan", "frustrasi", "tidak_terdeteksi"]
    OPSI_INSIDEN   = ["0x", "1x", "2x"]

    # 1. Bikin 405 tiket dasar
    kombinasi_dasar = list(itertools.product(
        LIST_KURIKULUM, LIST_TIPE, OPSI_KOGNITIF, OPSI_EMOSI, OPSI_INSIDEN, OPSI_INSIDEN
    ))

    # 2. Pengali untuk mencapai target 1667
    semua_tiket = kombinasi_dasar * 4 # 405 x 4 = 1620
    tiket_bonus = random.choices(kombinasi_dasar, k=47) # sisa 47 tiket
    total_tiket_1667 = semua_tiket + tiket_bonus

    # 3. Bikin tumpukan stempel Gaya Bahasa (1000 Informal, 667 Formal)
    tumpukan_stempel = ["informal"] * 1000 + ["formal"] * 667
    random.shuffle(tumpukan_stempel)

    # 4. Cap stempel ke setiap tiket
    tiket_final_1667 = []
    for i in range(1667):
        tiket_baru = list(total_tiket_1667[i]) + [tumpukan_stempel[i]]
        tiket_final_1667.append(tiket_baru)

    random.shuffle(tiket_final_1667)

    with open(FILE_BUKU_ABSEN, "w") as f:
        json.dump(tiket_final_1667, f)
    print("1.667 Tiket Khusus Materi berhasil dicetak!\n")

# ==========================================
# TAHAP B: AMBIL TIKET DARI BUKU ABSEN
# ==========================================
with open(FILE_BUKU_ABSEN, "r") as f:
    daftar_antrean = json.load(f)

print(f"Sisa tiket keseluruhan di Drive: {len(daftar_antrean)}")

if len(daftar_antrean) == 0:
    print("SELAMAT! Target 1.666 data materimu sudah selesai semua.")
else:
    tiket_diambil = min(TARGET_JUMLAH_DATA, len(daftar_antrean))
    tiket_hari_ini = daftar_antrean[:tiket_diambil]

    daftar_antrean = daftar_antrean[tiket_diambil:]
    with open(FILE_BUKU_ABSEN, "w") as f:
        json.dump(daftar_antrean, f)

    print(f"Memulai generate {len(tiket_hari_ini)} data baru... (Sisa tiket untuk besok: {len(daftar_antrean)})\n")

    tiket_gagal = []

    # ==========================================
    # TAHAP C: PROSES GENERATE KE API LLM
    # ==========================================
    for i, tiket in enumerate(tiket_hari_ini):
        urutan_kurikulum, urutan_tipe, sk_kognitif, sk_emosi, sk_oot, sk_bad, sk_gaya_bahasa = tiket

        PATH_BASE_SYS = os.path.join(ROOT_DIR, f"base_system_{sk_gaya_bahasa}.md")
        PATH_BASE_USR = os.path.join(ROOT_DIR, f"base_user_{sk_gaya_bahasa}.md")

        DIR_KOMPONEN_SYS = os.path.join(ROOT_DIR, f"komponen_system_{sk_gaya_bahasa}/")
        DIR_KOMPONEN_USR = os.path.join(ROOT_DIR, f"komponen_user_{sk_gaya_bahasa}/")

        status_berhasil_per_tiket = False
        current_temp = round(random.uniform(0.75, 0.95), 2)

        # Mencari file JSON materi yang sesuai kurikulum
        kandidat_file = []
        for f in daftar_file_sumber:
            f_norm = f.replace("\\", "/")
            if f"/{urutan_kurikulum}/" in f_norm and f"/{urutan_tipe}/" in f_norm:
                kandidat_file.append(f)

        if len(kandidat_file) > 0:
            file_terpilih = random.choice(kandidat_file)
        else:
            file_terpilih = random.choice(daftar_file_sumber)

        nama_file_saja = os.path.basename(file_terpilih)

        with open(file_terpilih, "r", encoding="utf-8") as f:
            data_json = json.load(f)

        meta = data_json.get("metadata", {})
        task_type = meta.get("task_type", "materi")

        # EKSTRAKSI BERSIH: HANYA MENGAMBIL MATERI (Tanpa logika pilgan/essay)
        teks_konteks_jadi = ""
        isi_assistant = data_json.get("assistant", {})
        if task_type == "materi":
            teks_konteks_jadi = isi_assistant.get("konten_markdown", "")

        # Pemanggilan string_evaluasi dihapus total, langsung suntik ke prefix
        prefix_siswa = f'[Emosi: {sk_emosi}]\n[Konteks: "{nama_file_saja}"]'

        print(f"[{i+1}/{len(tiket_hari_ini)}] Kurikulum: {urutan_kurikulum} | Tipe: {task_type.upper()} | Emosi: {sk_emosi} | Kognitif: {sk_kognitif} | OOT:{sk_oot} | Bad:{sk_bad} | Gaya: {sk_gaya_bahasa.upper()}")

        sys_p, usr_p, turn_terpakai = get_prompts_dinamis(sk_kognitif, sk_emosi, sk_oot, sk_bad, teks_konteks_jadi, prefix_siswa)

        payload = {
            "model": MODEL_NAME,
            "messages": [
                {"role": "system", "content": sys_p},
                {"role": "user", "content": usr_p}
            ],
            "temperature": current_temp,
            "max_tokens": 8192
        }
        headers = {"Authorization": f"Bearer {API_KEY}", "Content-Type": "application/json"}

        for attempt in range(MAX_RETRIES):
            try:
                response = requests.post(URL, headers=headers, json=payload, timeout=120)
                if response.status_code == 200:
                    raw_content = response.json().get('choices', [{}])[0].get('message', {}).get('content')

                    raw_content = raw_content.strip()
                    if raw_content.startswith('```json'):
                        raw_content = raw_content[7:]
                    elif raw_content.startswith('```'):
                        raw_content = raw_content[3:]
                    if raw_content.endswith('```'):
                        raw_content = raw_content[:-3]

                    raw_content = raw_content.strip()

                    try:
                        dialog_json = json.loads(raw_content, strict=False)
                    except json.JSONDecodeError:
                        continue

                    pesan_dialog = dialog_json if isinstance(dialog_json, list) else dialog_json.get("messages", [])

                    if pesan_dialog and pesan_dialog[-1]["role"] == "assistant":
                        pesan_percakapan = [msg for msg in pesan_dialog if msg["role"] != "system"]
                        turn_asli = len(pesan_percakapan) // 2

                        hasil_dataset.append({
                            "metadata": {
                                "mapel": meta.get("mata_pelajaran", "IPS"),
                                "kurikulum": meta.get("kurikulum", "Kurikulum Merdeka"),
                                "bab": meta.get("bab_judul", ""),
                                "subbab": meta.get("sub_bab", ""),
                                "tipe_konteks": task_type,
                                "level_konteks": meta.get("level", ""),
                                "skenario_emosi": sk_emosi,
                                "skenario_kognitif": sk_kognitif,
                                "skenario_oot": sk_oot,
                                "skenario_bad": sk_bad,
                                "skenario_gaya_bahasa": sk_gaya_bahasa,
                                "path_file_sumber": file_terpilih,
                                "temp_used": current_temp,
                                "turn": turn_asli,
                                "model": MODEL_NAME
                            },
                            "messages": [
                                {"role": "system", "content": f"ips_sys_{task_type}_{sk_emosi}_{sk_kognitif}_oot{sk_oot}_bad{sk_bad}_{sk_gaya_bahasa}"}
                            ] + pesan_percakapan
                        })
                        jumlah_sukses += 1
                        status_berhasil_per_tiket = True
                        print(f"  -> Berhasil.")
                        time.sleep(3)
                        break
                    else:
                        print("  -> Dialog gagal/berhenti di user. (Mencoba ulang...)")
                else:
                    print(f"  -> Error API {response.status_code}")
                    time.sleep(15)
            except Exception as e:
                print(f"  -> Exception: {e}")
                time.sleep(5)

        if not status_berhasil_per_tiket:
            tiket_gagal.append(tiket)
            print("  -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.\n")

    # ==========================================
    # TAHAP D: REFUND TIKET GAGAL KE DRIVE
    # ==========================================
    if len(tiket_gagal) > 0:
        print(f"\nMengembalikan {len(tiket_gagal)} tiket yang hangus ke Buku Absen di Drive...")

        with open(FILE_BUKU_ABSEN, "r") as f:
            antrean_sekarang = json.load(f)

        antrean_sekarang.extend(tiket_gagal)
        random.shuffle(antrean_sekarang)

        with open(FILE_BUKU_ABSEN, "w") as f:
            json.dump(antrean_sekarang, f)

        print("Refund tiket berhasil!")

    print(f"\nSelesai. Berhasil generate: {jumlah_sukses}/{len(tiket_hari_ini)} percakapan.")
# Out:
# Sisa tiket keseluruhan di Drive: 100
# Memulai generate 100 data baru... (Sisa tiket untuk besok: 0)
#
# [1/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [2/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [3/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [4/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [5/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [6/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [7/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [8/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [9/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [10/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [11/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [12/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [13/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [14/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [15/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [16/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [17/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [18/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [19/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [20/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [21/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [22/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [23/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [24/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [25/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [26/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [27/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [28/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Dialog gagal/berhenti di user. (Mencoba ulang...)
#   -> Berhasil.
# [29/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [30/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [31/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [32/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [33/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [34/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [35/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [36/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [37/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [38/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Dialog gagal/berhenti di user. (Mencoba ulang...)
#   -> Berhasil.
# [39/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [40/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [41/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [42/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [43/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [44/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [45/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [46/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [47/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [48/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [49/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [50/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [51/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [52/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [53/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [54/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [55/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [56/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [57/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [58/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [59/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [60/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [61/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [62/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [63/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [64/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [65/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [66/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [67/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [68/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [69/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [70/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [71/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [72/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [73/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [74/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [75/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [76/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Dialog gagal/berhenti di user. (Mencoba ulang...)
#   -> Berhasil.
# [77/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [78/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Dialog gagal/berhenti di user. (Mencoba ulang...)
#   -> Berhasil.
# [79/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [80/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [81/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [82/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [83/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [84/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [85/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [86/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [87/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [88/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [89/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [90/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [91/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Dialog gagal/berhenti di user. (Mencoba ulang...)
#   -> Berhasil.
# [92/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [93/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [94/100] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [95/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [96/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [97/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [98/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [99/100] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [100/100] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
#
# Selesai. Berhasil generate: 100/100 percakapan.

# %% [markdown]
# # CELL 6 — Simpan ke Google Drive

# %%
CUSTOM_OUTPUT_PATH = "/content/drive/MyDrive/output_sft_baru/" # sesuaikan nama folder

if 'hasil_dataset' in globals() and len(hasil_dataset) > 0:
    os.makedirs(CUSTOM_OUTPUT_PATH, exist_ok=True) # Otomatis buat folder jika tidak ada

    # Nama file global
    nama_file  = f"final_materi_{MATA_PELAJARAN}.json"
    full_path  = os.path.join(CUSTOM_OUTPUT_PATH, nama_file)
    data_final = []

    if os.path.exists(full_path):
        try:
            with open(full_path, "r", encoding="utf-8") as f:
                data_final = json.load(f)
        except Exception:
            pass

    # menambahkan data baru ke file yang sudah ada
    data_final.extend(hasil_dataset)

    try:
        with open(full_path, "w", encoding="utf-8") as f:
            json.dump(data_final, f, ensure_ascii=False, indent=4)
        print(f"Tersimpan: {len(data_final)} baris -> {full_path}")
        hasil_dataset.clear()
    except Exception as e:
        print(f"Gagal menyimpan: {e}")
# Out:
# Tersimpan: 1667 baris -> /content/drive/MyDrive/output_sft_baru/final_materi_IPS.json

# %% [markdown]
# "Stratifikasi sosial memang menunjukkan adanya pelapisan dalam masyarakat berdasarkan nilai-nilai yang dianggap penting, seperti kekayaan atau pendidikan. Ini adalah pengamatan terhadap realitas sosial, bukan sebuah anjuran.
# > Berdasarkan teks, hal-hal apa saja yang bisa menjadi dasar terjadinya pelapisan sosial?"

# %% [markdown]
# Cuaca dan iklim memang sering dianggap sama, tetapi sebenarnya berbeda. Berdasarkan teks, **cuaca** adalah keadaan udara pada wilayah yang sempit dan waktu tertentu. Contohnya adalah \"besok pagi di Surabaya akan cerah\".
#
# > Apa yang dimaksud dengan **iklim** berdasarkan teks tersebut?

# %% [markdown]
# Menarik sekali ide tentang film animasi. Namun, untuk saat ini, mari kita fokus kembali pada materi IPS ini.
#
# Kamu benar bahwa **angin** adalah pergerakan udara dari daerah bertekanan tinggi ke daerah bertekanan rendah.
#
# > Lalu, apakah Indonesia memiliki iklim tropis atau iklim yang lain?
