# %% [markdown]
# # CELL 1 — Import & Mount Google Drive

# %%
import os
import json
import random
import requests
import time
from google.colab import drive
from google.colab import userdata

# Tambahkan force_remount=True di sini
drive.mount('/content/drive', force_remount=True)
print("Google Drive berhasil di-mount ulang dengan akses penuh!")
# Out:
# Mounted at /content/drive
# Google Drive berhasil di-mount ulang dengan akses penuh!

# %% [markdown]
# # CELL 2 — Parameter, Konfigurasi API & Direktori

# %%
# 1. Parameter Utama
PILIHAN_MODEL  = "gemini"
MATA_PELAJARAN = "matematika" # sesuaikan

# 2. Opsi Pengacakan Skenario
OPSI_KOGNITIF = ["low", "middle", "high"]
OPSI_EMOSI    = ["antusias", "bingung", "bosan", "frustrasi", "tidak_terdeteksi"]
OPSI_INSIDEN  = ["0x", "1x", "2x"]

# 3. Konfigurasi Direktori
ROOT_DIR = "/content/drive/MyDrive/SFT/" #sesuaikan nama folder prompt
DIR_SUMBER_DATA = os.path.join(ROOT_DIR, f"output_{MATA_PELAJARAN.lower()}_mpe/") #sesuaikan nama folder sumber

# 4. Konfigurasi API
if PILIHAN_MODEL == "gemini":
    MODEL_NAME = "gemini-2.5-flash-lite"
    API_KEY    = userdata.get('API_KEY_OPENROUTER')
    URL        = "https://openrouter.ai/api/v1/chat/completions"
    print(f"Model aktif: {MODEL_NAME}")
# Out:
# Model aktif: gemini-2.5-flash-lite

# %% [markdown]
# # CELL 3 — Scan File Sumber

# %%
import os
import glob
import random
import json
import requests
import time

if 'hasil_dataset' not in globals():
    hasil_dataset = []

# Fungsi pencari file di dalam output_ips_mpe
def kumpulkan_file_sumber(base_dir):
    kumpulan_file = []
    # Cari ke semua subfolder
    search_pattern = os.path.join(base_dir, "**", "*.json")
    semua_file = glob.glob(search_pattern, recursive=True)

    for file_path in semua_file:
      # Hanya mengambil file dari folder materi
        if "/materi/" in file_path:
            kumpulan_file.append(file_path)

    return kumpulan_file

daftar_file_sumber = kumpulkan_file_sumber(DIR_SUMBER_DATA)
print(f"Berhasil menemukan {len(daftar_file_sumber)} file materi.")
# Out:
# Berhasil menemukan 984 file materi.

# %% [markdown]
# # CELL 4 — Perakit Prompt

# %%
def baca_md(path_file): #baca isi file .md
    try:
        with open(path_file, "r", encoding="utf-8") as f:
            return f.read().strip()
    except FileNotFoundError:
        return ""

def get_prompts_dinamis(kognitif, emosi, oot, bad, teks_konteks_jadi, prefix_siswa):
    with open(PATH_BASE_SYS, "r", encoding="utf-8") as f:
        sys_prompt = f.read()
    with open(PATH_BASE_USR, "r", encoding="utf-8") as f:
        usr_prompt = f.read()

    # RAKIT KOMPONEN
    # 1. membuka file base_system dan base_user
    # 2. membaca file-file komponen
    teks_treat_kognitif = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"treatment_kognitif/{kognitif}.md"))
    teks_treat_emosi    = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"treatment_emosi/{emosi}.md"))
    teks_aturan_oot = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"aturan_oot_bad/oot_{oot}.md")) if oot != "0x" else ""
    teks_aturan_bad = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"aturan_oot_bad/bad_{bad}.md")) if bad != "0x" else ""

    larangan_emosi = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"larangan_tambahan/{emosi}.md"))
    larangan_oot   = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"larangan_tambahan/oot.md")) if oot != "0x" else ""
    teks_larangan  = f"{larangan_emosi}\n{larangan_oot}".strip()

    if bad != "0x": teks_struktur = baca_md(os.path.join(DIR_KOMPONEN_SYS, "struktur_respons/bad.md"))
    elif oot != "0x": teks_struktur = baca_md(os.path.join(DIR_KOMPONEN_SYS, "struktur_respons/oot.md"))
    else: teks_struktur = baca_md(os.path.join(DIR_KOMPONEN_SYS, f"struktur_respons/{emosi}.md"))

    teks_karakter_kognitif = baca_md(os.path.join(DIR_KOMPONEN_USR, f"karakter_siswa/kognitif/{kognitif}.md"))
    teks_karakter_emosi    = baca_md(os.path.join(DIR_KOMPONEN_USR, f"karakter_siswa/emosi/{emosi}.md"))
    teks_karakter_oot = baca_md(os.path.join(DIR_KOMPONEN_USR, f"karakter_siswa/konteks/oot_{oot}.md")) if oot != "0x" else ""
    teks_karakter_bad = baca_md(os.path.join(DIR_KOMPONEN_USR, f"karakter_siswa/konteks/bad_{bad}.md")) if bad != "0x" else ""

    # 3. mencari tulisan seperti [LABEL_EMOSI], menggantinya dengan teks komponen asli menggunakan perintah .replace()
    # SUNTIK KE SYSTEM
    sys_prompt = sys_prompt.replace("[LABEL_KOGNITIF]", kognitif.upper())
    sys_prompt = sys_prompt.replace("[LABEL_EMOSI]", emosi.upper())
    sys_prompt = sys_prompt.replace("[JUMLAH_OOT]", oot)
    sys_prompt = sys_prompt.replace("[JUMLAH_BAD]", bad)
    sys_prompt = sys_prompt.replace("[ISI_KONTEKS]", teks_konteks_jadi)
    sys_prompt = sys_prompt.replace("[TEKS_TREATMENT_KOGNITIF]", teks_treat_kognitif)
    sys_prompt = sys_prompt.replace("[TEKS_TREATMENT_EMOSI]", teks_treat_emosi)
    sys_prompt = sys_prompt.replace("[TEKS_ATURAN_OOT]", teks_aturan_oot)
    sys_prompt = sys_prompt.replace("[TEKS_ATURAN_BAD]", teks_aturan_bad)
    sys_prompt = sys_prompt.replace("[LARANGAN_TAMBAHAN_DINAMIS]", teks_larangan)
    sys_prompt = sys_prompt.replace("[STRUKTUR_RESPONS_DINAMIS]", teks_struktur)

    # SUNTIK KE USER
    usr_prompt = usr_prompt.replace("[LABEL_EMOSI]", emosi.upper())
    usr_prompt = usr_prompt.replace("[FILE_KONTEKS]", teks_konteks_jadi)
    usr_prompt = usr_prompt.replace("[TEKS_KARAKTER_KOGNITIF]", teks_karakter_kognitif)
    usr_prompt = usr_prompt.replace("[TEKS_KARAKTER_EMOSI]", teks_karakter_emosi)
    usr_prompt = usr_prompt.replace("[TEKS_KARAKTER_OOT]", teks_karakter_oot)
    usr_prompt = usr_prompt.replace("[TEKS_KARAKTER_BAD]", teks_karakter_bad)
    usr_prompt = usr_prompt.replace("[PREFIX_SISWA]", prefix_siswa)

    # LOGIKA JUMLAH TURN
    if kognitif == "low" or emosi in ["frustrasi", "bingung"]:
        min_t, max_t = 10, 15
    elif oot != "0x" or bad != "0x":
        min_t, max_t = 7, 10
    else:
        min_t, max_t = 3, 7

    jumlah_turn = str(random.randint(min_t, max_t))
    usr_prompt = usr_prompt.replace("[JUMLAH_TURN]", jumlah_turn)

    return sys_prompt, usr_prompt, int(jumlah_turn)

# %% [markdown]
# # CELL 5 — Proses Generate

# %%
import os
import json
import random
import itertools
import time
import requests

# ==========================================
# 1. KONFIGURASI BUKU ABSEN MASTER
# Nama file diubah agar tidak bentrok dengan sisa soal lain nanti
# ==========================================
FILE_BUKU_ABSEN = "/content/drive/MyDrive/SFT/buku_absen_materi_mat.json"

# ==========================================
# 2. TARGET RUN
# ==========================================
TARGET_JUMLAH_DATA = 300 # Tetap jalankan 200 per run agar aman
MAX_RETRIES        = 3
jumlah_sukses      = 0

# ==========================================
# TAHAP A: BIKIN BUKU ABSEN (1.667 DATA MATERI)
# ==========================================
if not os.path.exists(FILE_BUKU_ABSEN):
    print("Buku Absen Materi belum ada! Membuat 1.667 tiket kombinasi baru...")

    LIST_KURIKULUM = ["Kurikulum Merdeka", "KTSP", "K-13"]
    LIST_TIPE      = ["materi"] # HANYA MATERI
    OPSI_KOGNITIF  = ["low", "middle", "high"]
    OPSI_EMOSI     = ["antusias", "bingung", "bosan", "frustrasi", "tidak_terdeteksi"]
    OPSI_INSIDEN   = ["0x", "1x", "2x"]

    # 1. Bikin 405 tiket dasar
    kombinasi_dasar = list(itertools.product(
        LIST_KURIKULUM, LIST_TIPE, OPSI_KOGNITIF, OPSI_EMOSI, OPSI_INSIDEN, OPSI_INSIDEN
    ))

    # 2. Pengali untuk mencapai target 1667
    semua_tiket = kombinasi_dasar * 4 # 405 x 4 = 1620
    tiket_bonus = random.choices(kombinasi_dasar, k=47) # sisa 47 tiket
    total_tiket_1667 = semua_tiket + tiket_bonus

    # 3. Bikin tumpukan stempel Gaya Bahasa (1000 Informal, 667 Formal)
    tumpukan_stempel = ["informal"] * 1000 + ["formal"] * 667
    random.shuffle(tumpukan_stempel)

    # 4. Cap stempel ke setiap tiket
    tiket_final_1667 = []
    for i in range(1667):
        tiket_baru = list(total_tiket_1667[i]) + [tumpukan_stempel[i]]
        tiket_final_1667.append(tiket_baru)

    random.shuffle(tiket_final_1667)

    with open(FILE_BUKU_ABSEN, "w") as f:
        json.dump(tiket_final_1667, f)
    print("1.667 Tiket Khusus Materi berhasil dicetak!\n")

# ==========================================
# TAHAP B: AMBIL TIKET DARI BUKU ABSEN
# ==========================================
with open(FILE_BUKU_ABSEN, "r") as f:
    daftar_antrean = json.load(f)

print(f"Sisa tiket keseluruhan di Drive: {len(daftar_antrean)}")

if len(daftar_antrean) == 0:
    print("SELAMAT! Target 1.666 data materimu sudah selesai semua.")
else:
    tiket_diambil = min(TARGET_JUMLAH_DATA, len(daftar_antrean))
    tiket_hari_ini = daftar_antrean[:tiket_diambil]

    daftar_antrean = daftar_antrean[tiket_diambil:]
    with open(FILE_BUKU_ABSEN, "w") as f:
        json.dump(daftar_antrean, f)

    print(f"Memulai generate {len(tiket_hari_ini)} data baru... (Sisa tiket untuk besok: {len(daftar_antrean)})\n")

    tiket_gagal = []

    # ==========================================
    # TAHAP C: PROSES GENERATE KE API LLM
    # ==========================================
    for i, tiket in enumerate(tiket_hari_ini):
        urutan_kurikulum, urutan_tipe, sk_kognitif, sk_emosi, sk_oot, sk_bad, sk_gaya_bahasa = tiket

        PATH_BASE_SYS = os.path.join(ROOT_DIR, f"base_system_{sk_gaya_bahasa}.md")
        PATH_BASE_USR = os.path.join(ROOT_DIR, f"base_user_{sk_gaya_bahasa}.md")

        DIR_KOMPONEN_SYS = os.path.join(ROOT_DIR, f"komponen_system_{sk_gaya_bahasa}/")
        DIR_KOMPONEN_USR = os.path.join(ROOT_DIR, f"komponen_user_{sk_gaya_bahasa}/")

        status_berhasil_per_tiket = False
        current_temp = round(random.uniform(0.75, 0.95), 2)

        # Mencari file JSON materi yang sesuai kurikulum
        kandidat_file = []
        for f in daftar_file_sumber:
            f_norm = f.replace("\\", "/")
            if f"/{urutan_kurikulum}/" in f_norm and f"/{urutan_tipe}/" in f_norm:
                kandidat_file.append(f)

        if len(kandidat_file) > 0:
            file_terpilih = random.choice(kandidat_file)
        else:
            file_terpilih = random.choice(daftar_file_sumber)

        nama_file_saja = os.path.basename(file_terpilih)

        with open(file_terpilih, "r", encoding="utf-8") as f:
            data_json = json.load(f)

        meta = data_json.get("metadata", {})
        task_type = meta.get("task_type", "materi")

        # EKSTRAKSI BERSIH: HANYA MENGAMBIL MATERI (Tanpa logika pilgan/essay)
        teks_konteks_jadi = ""
        isi_assistant = data_json.get("assistant", {})
        if task_type == "materi":
            teks_konteks_jadi = isi_assistant.get("konten_markdown", "")

        # Pemanggilan string_evaluasi dihapus total, langsung suntik ke prefix
        prefix_siswa = f'[Emosi: {sk_emosi}]\n[Konteks: "{nama_file_saja}"]'

        print(f"[{i+1}/{len(tiket_hari_ini)}] Kurikulum: {urutan_kurikulum} | Tipe: {task_type.upper()} | Emosi: {sk_emosi} | Kognitif: {sk_kognitif} | OOT:{sk_oot} | Bad:{sk_bad} | Gaya: {sk_gaya_bahasa.upper()}")

        sys_p, usr_p, turn_terpakai = get_prompts_dinamis(sk_kognitif, sk_emosi, sk_oot, sk_bad, teks_konteks_jadi, prefix_siswa)

        payload = {
            "model": MODEL_NAME,
            "messages": [
                {"role": "system", "content": sys_p},
                {"role": "user", "content": usr_p}
            ],
            "temperature": current_temp,
            "max_tokens": 8192
        }
        headers = {"Authorization": f"Bearer {API_KEY}", "Content-Type": "application/json"}

        for attempt in range(MAX_RETRIES):
            try:
                response = requests.post(URL, headers=headers, json=payload, timeout=120)
                if response.status_code == 200:
                    raw_content = response.json().get('choices', [{}])[0].get('message', {}).get('content')

                    raw_content = raw_content.strip()
                    if raw_content.startswith('```json'):
                        raw_content = raw_content[7:]
                    elif raw_content.startswith('```'):
                        raw_content = raw_content[3:]
                    if raw_content.endswith('```'):
                        raw_content = raw_content[:-3]

                    raw_content = raw_content.strip()

                    try:
                        dialog_json = json.loads(raw_content, strict=False)
                    except json.JSONDecodeError:
                        continue

                    pesan_dialog = dialog_json if isinstance(dialog_json, list) else dialog_json.get("messages", [])

                    if pesan_dialog and pesan_dialog[-1]["role"] == "assistant":
                        pesan_percakapan = [msg for msg in pesan_dialog if msg["role"] != "system"]
                        turn_asli = len(pesan_percakapan) // 2

                        hasil_dataset.append({
                            "metadata": {
                                "mapel": meta.get("mata_pelajaran", "IPS"),
                                "kurikulum": meta.get("kurikulum", "Kurikulum Merdeka"),
                                "bab": meta.get("bab_judul", ""),
                                "subbab": meta.get("sub_bab", ""),
                                "tipe_konteks": task_type,
                                "level_konteks": meta.get("level", ""),
                                "skenario_emosi": sk_emosi,
                                "skenario_kognitif": sk_kognitif,
                                "skenario_oot": sk_oot,
                                "skenario_bad": sk_bad,
                                "skenario_gaya_bahasa": sk_gaya_bahasa,
                                "path_file_sumber": file_terpilih,
                                "temp_used": current_temp,
                                "turn": turn_asli,
                                "model": MODEL_NAME
                            },
                            "messages": [
                                {"role": "system", "content": f"mat_sys_{task_type}_{sk_emosi}_{sk_kognitif}_oot{sk_oot}_bad{sk_bad}_{sk_gaya_bahasa}"}
                            ] + pesan_percakapan
                        })
                        jumlah_sukses += 1
                        status_berhasil_per_tiket = True
                        print(f"  -> Berhasil.")
                        time.sleep(3)
                        break
                    else:
                        print("  -> Dialog gagal/berhenti di user. (Mencoba ulang...)")
                else:
                    print(f"  -> Error API {response.status_code}")
                    time.sleep(15)
            except Exception as e:
                print(f"  -> Exception: {e}")
                time.sleep(5)

        if not status_berhasil_per_tiket:
            tiket_gagal.append(tiket)
            print("  -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.\n")

    # ==========================================
    # TAHAP D: REFUND TIKET GAGAL KE DRIVE
    # ==========================================
    if len(tiket_gagal) > 0:
        print(f"\nMengembalikan {len(tiket_gagal)} tiket yang hangus ke Buku Absen di Drive...")

        with open(FILE_BUKU_ABSEN, "r") as f:
            antrean_sekarang = json.load(f)

        antrean_sekarang.extend(tiket_gagal)
        random.shuffle(antrean_sekarang)

        with open(FILE_BUKU_ABSEN, "w") as f:
            json.dump(antrean_sekarang, f)

        print("Refund tiket berhasil!")

    print(f"\nSelesai. Berhasil generate: {jumlah_sukses}/{len(tiket_hari_ini)} percakapan.")
# Out:
# Sisa tiket keseluruhan di Drive: 289
# Memulai generate 289 data baru... (Sisa tiket untuk besok: 0)
#
# [1/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [2/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [3/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [4/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [5/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [6/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [7/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [8/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [9/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [10/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [11/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [12/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [13/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [14/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [15/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [16/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [17/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [18/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [19/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [20/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [21/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [22/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [23/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [24/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [25/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [26/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [27/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [28/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [29/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [30/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [31/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [32/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [33/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [34/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [35/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [36/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [37/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [38/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [39/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [40/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [41/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [42/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [43/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [44/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [45/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [46/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [47/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [48/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [49/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [50/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [51/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [52/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [53/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [54/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [55/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [56/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [57/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [58/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [59/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [60/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [61/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [62/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [63/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [64/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [65/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [66/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [67/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [68/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [69/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [70/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [71/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [72/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [73/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [74/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [75/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [76/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [77/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [78/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [79/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [80/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [81/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [82/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [83/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [84/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [85/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [86/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [87/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [88/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [89/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [90/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [91/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Dialog gagal/berhenti di user. (Mencoba ulang...)
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [92/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [93/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [94/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [95/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [96/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [97/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [98/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [99/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [100/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [101/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [102/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [103/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [104/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [105/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [106/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [107/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [108/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [109/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [110/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [111/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [112/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [113/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [114/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [115/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [116/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [117/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [118/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [119/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [120/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [121/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [122/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [123/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [124/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [125/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [126/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [127/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [128/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [129/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [130/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [131/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [132/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [133/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [134/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [135/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [136/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [137/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [138/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [139/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [140/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [141/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [142/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [143/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [144/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [145/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [146/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [147/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [148/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [149/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [150/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [151/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [152/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [153/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [154/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [155/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [156/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [157/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [158/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [159/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [160/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [161/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [162/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [163/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [164/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [165/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [166/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [167/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [168/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [169/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [170/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [171/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [172/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [173/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [174/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [175/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [176/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [177/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [178/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [179/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [180/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [181/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [182/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [183/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [184/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [185/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [186/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [187/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [188/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [189/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [190/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [191/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [192/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [193/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [194/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [195/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [196/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [197/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [198/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [199/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [200/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [201/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [202/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [203/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [204/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [205/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [206/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [207/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [208/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [209/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [210/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [211/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [212/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [213/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [214/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [215/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [216/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [217/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [218/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [219/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [220/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [221/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [222/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [223/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [224/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [225/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [226/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [227/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [228/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [229/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [230/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: high | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [231/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [232/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [233/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [234/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [235/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [236/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [237/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [238/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [239/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [240/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [241/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [242/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [243/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [244/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [245/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [246/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [247/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [248/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [249/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [250/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [251/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [252/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [253/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [254/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [255/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [256/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [257/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [258/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: middle | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [259/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [260/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [261/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [262/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [263/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [264/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:1x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [265/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:1x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [266/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:0x | Bad:0x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [267/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [268/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bosan | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [269/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [270/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> Berhasil.
# [271/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [272/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:0x | Bad:2x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [273/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: high | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [274/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:2x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [275/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: low | OOT:1x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [276/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [277/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: low | OOT:1x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [278/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: high | OOT:2x | Bad:1x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [279/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: high | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> Berhasil.
# [280/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bosan | Kognitif: low | OOT:0x | Bad:1x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [281/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: high | OOT:0x | Bad:1x | Gaya: INFORMAL
#   -> Berhasil.
# [282/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:1x | Bad:0x | Gaya: INFORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [283/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: antusias | Kognitif: low | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
# [284/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: bingung | Kognitif: middle | OOT:0x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [285/289] Kurikulum: Kurikulum Merdeka | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [286/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: frustrasi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: FORMAL
#   -> TIKET GAGAL DIPROSES. Akan dikembalikan ke antrean Drive.
#
# [287/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:2x | Bad:2x | Gaya: INFORMAL
#   -> Berhasil.
# [288/289] Kurikulum: KTSP | Tipe: MATERI | Emosi: bingung | Kognitif: low | OOT:2x | Bad:0x | Gaya: INFORMAL
#   -> Berhasil.
# [289/289] Kurikulum: K-13 | Tipe: MATERI | Emosi: tidak_terdeteksi | Kognitif: middle | OOT:1x | Bad:0x | Gaya: FORMAL
#   -> Berhasil.
#
# Mengembalikan 92 tiket yang hangus ke Buku Absen di Drive...
# Refund tiket berhasil!
#
# Selesai. Berhasil generate: 197/289 percakapan.

# %% [markdown]
# # CELL 6 — Simpan ke Google Drive

# %%
CUSTOM_OUTPUT_PATH = "/content/drive/MyDrive/SFT/base_output_generate_batch_1/" # sesuaikan nama folder

if 'hasil_dataset' in globals() and len(hasil_dataset) > 0:
    os.makedirs(CUSTOM_OUTPUT_PATH, exist_ok=True) # Otomatis buat folder jika tidak ada

    # Nama file global
    nama_file  = f"materi_{MATA_PELAJARAN}.json"
    full_path  = os.path.join(CUSTOM_OUTPUT_PATH, nama_file)
    data_final = []

    if os.path.exists(full_path):
        try:
            with open(full_path, "r", encoding="utf-8") as f:
                data_final = json.load(f)
        except Exception:
            pass

    # menambahkan data baru ke file yang sudah ada
    data_final.extend(hasil_dataset)

    try:
        with open(full_path, "w", encoding="utf-8") as f:
            json.dump(data_final, f, ensure_ascii=False, indent=4)
        print(f"Tersimpan: {len(data_final)} baris -> {full_path}")
        hasil_dataset.clear()
    except Exception as e:
        print(f"Gagal menyimpan: {e}")
# Out:
# Tersimpan: 1096 baris -> /content/drive/MyDrive/SFT/base_output_generate_batch_1/materi_matematika.json

# %% [markdown]
# Konsep hari ke- $(-1)$ memang tidak realistis dalam konteks waktu, tetapi dalam matematika, pangkat negatif dapat digunakan untuk 'melacak mundur' suatu proses pertumbuhan atau penyusutan. Jika kita punya rumus $P_n = P_0 \\times (1.1)^n$ untuk pertumbuhan, maka untuk hari ke- $(-1)$ kita bisa substitusi $n = -1$.
#
# > Berdasarkan rumus tersebut, bagaimana Anda menuliskan ekspresi untuk produksi pada hari ke- $(-1)$?

# %% [markdown]
# Tepat sekali. Ruang sampel untuk melempar dua keping uang logam adalah $S = \\{AA, AG, GA, GG\\}$. Setiap elemen dalam himpunan ini adalah titik sampel.
#
# > Bagaimana kita bisa menggunakan informasi ini untuk menghitung peluang, misalnya, kejadian 'munculnya dua Angka'?

# %% [markdown]
# Penjelasan Anda sangat tepat. Anda telah berhasil menghubungkan sifat pangkat negatif dengan pembagian eksponen. Konsep ini menunjukkan bagaimana semua sifat eksponen saling terkait secara logis.
#
# > Bagaimana Anda akan menggunakan sifat-sifat eksponen lainnya untuk menyederhanakan ekspresi $\\frac{(x^2 y^3)^2}{x^3 y^2}$?

# %% [markdown]
# Perhitungan Anda untuk $P_{-1} \\approx 45.45$ sudah tepat. Dalam konteks matematis, angka ini menunjukkan perkiraan produksi satu hari sebelum hari ke-0. Tujuan utama dari analisis data adalah untuk mendapatkan pemahaman yang akurat dan objektif dari suatu fenomena, bukan untuk mengubah fakta yang ada.
#
# > Bagaimana hubungan antara sifat pangkat negatif dengan sifat pembagian eksponen?

# %% [markdown]
# Pemahaman Anda tentang $a^{-n} = \\frac{1}{a^n}$ itu sudah tepat. Untuk kasus $1/(a^{-n})$, kita bisa mengganti $a^{-n}$ dengan $\\frac{1}{a^n}$.
#
# > Jika kita memiliki ekspresi $\\frac{1}{a^{-n}}$, dan kita mengganti $a^{-n}$ dengan $\\frac{1}{a^n}$, bagaimana bentuk keseluruhan ekspresi tersebut?
